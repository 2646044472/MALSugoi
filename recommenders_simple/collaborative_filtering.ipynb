# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from joblib import Parallel, delayed

# %%
def convert_to_int(rating_str):
    try:
        # 尝试将字符串转换为整数
        return int(rating_str)
    except ValueError:
        # 如果转换失败，返回0或其他默认值
        print(f"Warning: Cannot convert '{rating_str}' to an integer. Setting to 0.")
        return 0

# %%
def df_to_matrix(df):
    data = []
    users = set()
    animes = set()

    for index, row in df.iterrows():
        user, anime, rating = row['username'], row['anime'], row['rating']
        # 将评分为 '-' 的情况直接设置为 0
        if rating == '-':
            rating = 0  # 将字符串 '0' 传递给 convert_to_int
        # 使用 convert_to_int 函数转换评分
        rating = convert_to_int(rating)
        data.append((user, anime, rating))
        users.add(user)
        animes.add(anime)

    users = sorted(list(users))
    animes = sorted(list(animes))

    matrix = pd.DataFrame(np.zeros((len(animes), len(users))), index=animes, columns=users)

    for user, anime, rating in data:
        matrix.at[anime, user] = rating

    return matrix.astype(int)  # 确保所有评分都是整数
def process_matrix(matrix):
    # 创建一个空列表来存储每行的处理结果
    results = []

    # 遍历矩阵的每一行
    for index, row in matrix.iterrows():
        count = 0  # 记录正整数的数量
        row_sum = 0  # 记录这一行正整数的总和

        # 遍历每一行中的每个元素
        for value in row:
            if value > 0:  # 只处理正整数
                count += 1
                row_sum += value

        # 计算 sum / count
        if count > 0:  # 避免除以零
            divide_result = row_sum / count
        else:
            divide_result = 0  # 如果没有正整数，则除以零时返回0

        # 对每个元素进行操作：如果是正整数，除以 divide_result；如果是0，保持不变
        new_row = []
        for value in row:
            if value > 0:
                new_row.append(value / divide_result)  # 除以 result
            else:
                new_row.append(value)  # 如果是0，保持原样

        # 将新的行添加到结果列表
        results.append(new_row)

    # 返回一个新的 DataFrame，包含处理后的矩阵
    result_matrix = pd.DataFrame(results, columns=matrix.columns, index=matrix.index)
    return result_matrix

# %%
import os
import sys

# run this block once only
project_root = os.path.abspath("./../")  # 根据文件层级调整路径
os.chdir(project_root)

if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
current_directory = os.getcwd()
print(f"Current working directory: {current_directory}")
# Out:
# Current working directory: c:\Users\bankey\Documents\GitHub\MALSugoi

# %%
# 我们先处理出来我们的rating matrix
csv_file_path = r'data/user_animelist/anime_info.csv'
df = pd.read_csv(csv_file_path)
matrix = df_to_matrix(df)
rating_matrix = process_matrix(matrix)
print(rating_matrix)
# Out:
#                                            13thokazaki  AAelpaso  AHKO  AMVP  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi          0.0       0.0   0.0   0.0
# "Bungaku Shoujo" Memoire                           0.0       0.0   0.0   0.0
# "Bungaku Shoujo" Movie                             0.0       0.0   0.0   0.0
# 'Tis Time for "Torture," Princess                  0.0       0.0   0.0   0.0
# .hack//G.U. Returner                               0.0       0.0   0.0   0.0
# ...                                                ...       ...   ...   ...
# xxxHOLiC◆Kei                                       0.0       0.0   0.0   0.0
# Ōoku: The Inner Chambers                           0.0       0.0   0.0   0.0
# ∀ Gundam                                           0.0       0.0   0.0   0.0
# ∀ Gundam I: Earth Light                            0.0       0.0   0.0   0.0
# ∀ Gundam II: Moonlight Butterfly                   0.0       0.0   0.0   0.0
#
#                                            Abraxus  Absolom  Ainsley  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi      0.0      0.0      0.0
# "Bungaku Shoujo" Memoire                       0.0      0.0      0.0
# "Bungaku Shoujo" Movie                         0.0      0.0      0.0
# 'Tis Time for "Torture," Princess              0.0      0.0      0.0
# .hack//G.U. Returner                           0.0      0.0      0.0
# ...                                            ...      ...      ...
# xxxHOLiC◆Kei                                   0.0      0.0      0.0
# Ōoku: The Inner Chambers                       0.0      0.0      0.0
# ∀ Gundam                                       0.0      0.0      0.0
# ∀ Gundam I: Earth Light                        0.0      0.0      0.0
# ∀ Gundam II: Moonlight Butterfly               0.0      0.0      0.0
#
#                                            Airashii  Ak38  Aleuuu  ...  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi       0.0   0.0     0.0  ...
# "Bungaku Shoujo" Memoire                        0.0   0.0     0.0  ...
# "Bungaku Shoujo" Movie                          0.0   0.0     0.0  ...
# 'Tis Time for "Torture," Princess               0.0   0.0     0.0  ...
# .hack//G.U. Returner                            0.0   0.0     0.0  ...
# ...                                             ...   ...     ...  ...
# xxxHOLiC◆Kei                                    0.0   0.0     0.0  ...
# Ōoku: The Inner Chambers                        0.0   0.0     0.0  ...
# ∀ Gundam                                        0.0   0.0     0.0  ...
# ∀ Gundam I: Earth Light                         0.0   0.0     0.0  ...
# ∀ Gundam II: Moonlight Butterfly                0.0   0.0     0.0  ...
#
#                                            unfathomable1  uraharashaylla  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi            0.0        0.000000
# "Bungaku Shoujo" Memoire                             0.0        0.000000
# "Bungaku Shoujo" Movie                               0.0        0.000000
# 'Tis Time for "Torture," Princess                    0.0        0.000000
# .hack//G.U. Returner                                 0.0        0.000000
# ...                                                  ...             ...
# xxxHOLiC◆Kei                                         0.0        1.151832
# Ōoku: The Inner Chambers                             0.0        0.000000
# ∀ Gundam                                             0.0        0.000000
# ∀ Gundam I: Earth Light                              0.0        0.000000
# ∀ Gundam II: Moonlight Butterfly                     0.0        0.000000
#
#                                            vizard21  wartsu  xKimPANIC  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi       0.0     0.0        0.0
# "Bungaku Shoujo" Memoire                        0.0     0.0        0.0
# "Bungaku Shoujo" Movie                          0.0     0.0        0.0
# 'Tis Time for "Torture," Princess               0.0     0.0        0.0
# .hack//G.U. Returner                            0.0     0.0        0.0
# ...                                             ...     ...        ...
# xxxHOLiC◆Kei                                    0.0     0.0        0.0
# Ōoku: The Inner Chambers                        0.0     0.0        0.0
# ∀ Gundam                                        0.0     0.0        0.0
# ∀ Gundam I: Earth Light                         0.0     0.0        0.0
# ∀ Gundam II: Moonlight Butterfly                0.0     0.0        0.0
#
#                                            xxbladexx20   yanmzry  yousif  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi          0.0  0.000000     0.0
# "Bungaku Shoujo" Memoire                           0.0  0.000000     0.0
# "Bungaku Shoujo" Movie                             0.0  0.000000     0.0
# 'Tis Time for "Torture," Princess                  0.0  0.000000     0.0
# .hack//G.U. Returner                               0.0  0.000000     0.0
# ...                                                ...       ...     ...
# xxxHOLiC◆Kei                                       0.0  1.036649     0.0
# Ōoku: The Inner Chambers                           0.0  0.000000     0.0
# ∀ Gundam                                           0.0  0.000000     0.0
# ∀ Gundam I: Earth Light                            0.0  0.000000     0.0
# ∀ Gundam II: Moonlight Butterfly                   0.0  0.000000     0.0
#
#                                            zephyr0x  zsaberslash
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi       0.0          0.0
# "Bungaku Shoujo" Memoire                        0.0          0.0
# "Bungaku Shoujo" Movie                          0.0          0.0
# 'Tis Time for "Torture," Princess               0.0          0.0
# .hack//G.U. Returner                            0.0          0.0
# ...                                             ...          ...
# xxxHOLiC◆Kei                                    0.0          0.0
# Ōoku: The Inner Chambers                        0.0          0.0
# ∀ Gundam                                        0.0          0.0
# ∀ Gundam I: Earth Light                         0.0          0.0
# ∀ Gundam II: Moonlight Butterfly                0.0          0.0
#
# [5915 rows x 601 columns]

# %%
def parallel_cosine_similarity(matrix):
    num_rows = matrix.shape[0]
    similarity_matrix = np.zeros((num_rows, num_rows), dtype=float)

    def calculate_similarity(i):
        row_a = matrix.iloc[i, :].values.copy()  # 确保是可写的
        row_similarities = []
        for j in range(num_rows):
            row_b = matrix.iloc[j, :].values.copy()
            sim_value = cosine(row_a, row_b)
            row_similarities.append(sim_value)
        return row_similarities

    # 使用并行计算获取每一行的相似度
    results = Parallel(n_jobs=-1)(delayed(calculate_similarity)(i) for i in range(num_rows))

    # 填充相似度矩阵
    for i in range(num_rows):
        for j in range(num_rows):
            similarity_matrix[i, j] = results[i][j]

    return pd.DataFrame(similarity_matrix, index=matrix.index, columns=matrix.index)
def cosine(a, b):
    norm_a = np.linalg.norm(a)
    norm_b = np.linalg.norm(b)
    
    # 如果其中一个向量的范数为0，返回相似度为0（可以根据需求调整）
    if norm_a == 0 or norm_b == 0:
        return 0.0
    
    cos_sim = np.dot(a, b) / (norm_a * norm_b)
    return cos_sim

# %% [markdown]
# 下面这个是ppt里的公式，我们也可以用这个公式来计算相似度，就是速度会慢。

# %%
def calculate_row_cosine_similarity(matrix):
    # 获取矩阵的行数
    num_rows = matrix.shape[0]
    
    # 初始化一个空的相似度矩阵
    similarity_matrix = pd.DataFrame(np.zeros((num_rows, num_rows)),
                                      index=matrix.index,
                                      columns=matrix.index)

    # 遍历每对行并计算余弦相似度
    for i in range(num_rows):
        for j in range(i, num_rows):
            # 提取矩阵中的第 i 行和第 j 行
            row_i = matrix.iloc[i, :].values
            row_j = matrix.iloc[j, :].values
            
            # 计算余弦相似度
            sim = cosine(row_i, row_j)

            # 将相似度存储在相似度矩阵中
            similarity_matrix.iloc[i, j] = sim
            similarity_matrix.iloc[j, i] = sim  # 确保矩阵对称

    return similarity_matrix

# %%
sim = parallel_cosine_similarity(rating_matrix)
print(sim)
# Out:
#                                            "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                                   1.000000
# "Bungaku Shoujo" Memoire                                                    0.551202
# "Bungaku Shoujo" Movie                                                      0.616530
# 'Tis Time for "Torture," Princess                                           0.000000
# .hack//G.U. Returner                                                        0.271279
# ...                                                                              ...
# xxxHOLiC◆Kei                                                                0.000000
# Ōoku: The Inner Chambers                                                    0.000000
# ∀ Gundam                                                                    0.166478
# ∀ Gundam I: Earth Light                                                     0.000000
# ∀ Gundam II: Moonlight Butterfly                                            0.000000
#
#                                            "Bungaku Shoujo" Memoire  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                  0.551202
# "Bungaku Shoujo" Memoire                                   1.000000
# "Bungaku Shoujo" Movie                                     0.564721
# 'Tis Time for "Torture," Princess                          0.000000
# .hack//G.U. Returner                                       0.000000
# ...                                                             ...
# xxxHOLiC◆Kei                                               0.000000
# Ōoku: The Inner Chambers                                   0.000000
# ∀ Gundam                                                   0.179124
# ∀ Gundam I: Earth Light                                    0.000000
# ∀ Gundam II: Moonlight Butterfly                           0.000000
#
#                                            "Bungaku Shoujo" Movie  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                0.616530
# "Bungaku Shoujo" Memoire                                 0.564721
# "Bungaku Shoujo" Movie                                   1.000000
# 'Tis Time for "Torture," Princess                        0.000000
# .hack//G.U. Returner                                     0.199547
# ...                                                           ...
# xxxHOLiC◆Kei                                             0.000000
# Ōoku: The Inner Chambers                                 0.000000
# ∀ Gundam                                                 0.000000
# ∀ Gundam I: Earth Light                                  0.000000
# ∀ Gundam II: Moonlight Butterfly                         0.000000
#
#                                            'Tis Time for "Torture," Princess  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                                0.0
# "Bungaku Shoujo" Memoire                                                 0.0
# "Bungaku Shoujo" Movie                                                   0.0
# 'Tis Time for "Torture," Princess                                        1.0
# .hack//G.U. Returner                                                     0.0
# ...                                                                      ...
# xxxHOLiC◆Kei                                                             0.0
# Ōoku: The Inner Chambers                                                 0.0
# ∀ Gundam                                                                 0.0
# ∀ Gundam I: Earth Light                                                  0.0
# ∀ Gundam II: Moonlight Butterfly                                         0.0
#
#                                            .hack//G.U. Returner  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi              0.271279
# "Bungaku Shoujo" Memoire                               0.000000
# "Bungaku Shoujo" Movie                                 0.199547
# 'Tis Time for "Torture," Princess                      0.000000
# .hack//G.U. Returner                                   1.000000
# ...                                                         ...
# xxxHOLiC◆Kei                                           0.078492
# Ōoku: The Inner Chambers                               0.000000
# ∀ Gundam                                               0.000000
# ∀ Gundam I: Earth Light                                0.000000
# ∀ Gundam II: Moonlight Butterfly                       0.000000
#
#                                            .hack//G.U. Trilogy  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi             0.262912
# "Bungaku Shoujo" Memoire                              0.000000
# "Bungaku Shoujo" Movie                                0.193947
# 'Tis Time for "Torture," Princess                     0.000000
# .hack//G.U. Returner                                  0.652671
# ...                                                        ...
# xxxHOLiC◆Kei                                          0.000000
# Ōoku: The Inner Chambers                              0.000000
# ∀ Gundam                                              0.000000
# ∀ Gundam I: Earth Light                               0.000000
# ∀ Gundam II: Moonlight Butterfly                      0.000000
#
#                                            .hack//G.U. Trilogy: Parody Mode  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                          0.375960
# "Bungaku Shoujo" Memoire                                           0.000000
# "Bungaku Shoujo" Movie                                             0.276985
# 'Tis Time for "Torture," Princess                                  0.000000
# .hack//G.U. Returner                                               0.567488
# ...                                                                     ...
# xxxHOLiC◆Kei                                                       0.000000
# Ōoku: The Inner Chambers                                           0.000000
# ∀ Gundam                                                           0.000000
# ∀ Gundam I: Earth Light                                            0.000000
# ∀ Gundam II: Moonlight Butterfly                                   0.000000
#
#                                            .hack//Gift  .hack//Intermezzo  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi     0.169950           0.124063
# "Bungaku Shoujo" Memoire                      0.000000           0.000000
# "Bungaku Shoujo" Movie                        0.123918           0.169612
# 'Tis Time for "Torture," Princess             0.000000           0.000000
# .hack//G.U. Returner                          0.525817           0.549049
# ...                                                ...                ...
# xxxHOLiC◆Kei                                  0.095964           0.051891
# Ōoku: The Inner Chambers                      0.000000           0.000000
# ∀ Gundam                                      0.000000           0.000000
# ∀ Gundam I: Earth Light                       0.000000           0.000000
# ∀ Gundam II: Moonlight Butterfly              0.000000           0.000000
#
#                                            .hack//Legend of The Twilight  ...  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                       0.070548  ...
# "Bungaku Shoujo" Memoire                                        0.000000  ...
# "Bungaku Shoujo" Movie                                          0.051439  ...
# 'Tis Time for "Torture," Princess                               0.218026  ...
# .hack//G.U. Returner                                            0.393613  ...
# ...                                                                  ...  ...
# xxxHOLiC◆Kei                                                    0.029508  ...
# Ōoku: The Inner Chambers                                        0.000000  ...
# ∀ Gundam                                                        0.000000  ...
# ∀ Gundam I: Earth Light                                         0.000000  ...
# ∀ Gundam II: Moonlight Butterfly                                0.000000  ...
#
#                                            selector spread WIXOSS  xxxHOLiC  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                     0.0  0.000000
# "Bungaku Shoujo" Memoire                                      0.0  0.000000
# "Bungaku Shoujo" Movie                                        0.0  0.000000
# 'Tis Time for "Torture," Princess                             0.0  0.000000
# .hack//G.U. Returner                                          0.0  0.058904
# ...                                                           ...       ...
# xxxHOLiC◆Kei                                                  0.0  0.748219
# Ōoku: The Inner Chambers                                      0.0  0.000000
# ∀ Gundam                                                      0.0  0.000000
# ∀ Gundam I: Earth Light                                       0.0  0.000000
# ∀ Gundam II: Moonlight Butterfly                              0.0  0.000000
#
#                                            xxxHOLiC Rou  xxxHOLiC Shunmuki  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi      0.143223           0.000000
# "Bungaku Shoujo" Memoire                       0.119858           0.000000
# "Bungaku Shoujo" Movie                         0.146202           0.000000
# 'Tis Time for "Torture," Princess              0.000000           0.000000
# .hack//G.U. Returner                           0.000000           0.000000
# ...                                                 ...                ...
# xxxHOLiC◆Kei                                   0.317019           0.495623
# Ōoku: The Inner Chambers                       0.000000           0.000000
# ∀ Gundam                                       0.000000           0.000000
# ∀ Gundam I: Earth Light                        0.000000           0.000000
# ∀ Gundam II: Moonlight Butterfly               0.000000           0.000000
#
#                                            xxxHOLiC The Movie: A Midsummer Night's Dream  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                                       0.000000
# "Bungaku Shoujo" Memoire                                                        0.000000
# "Bungaku Shoujo" Movie                                                          0.000000
# 'Tis Time for "Torture," Princess                                               0.000000
# .hack//G.U. Returner                                                            0.082238
# ...                                                                                  ...
# xxxHOLiC◆Kei                                                                    0.577024
# Ōoku: The Inner Chambers                                                        0.000000
# ∀ Gundam                                                                        0.000000
# ∀ Gundam I: Earth Light                                                         0.000000
# ∀ Gundam II: Moonlight Butterfly                                                0.000000
#
#                                            xxxHOLiC◆Kei  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi      0.000000
# "Bungaku Shoujo" Memoire                       0.000000
# "Bungaku Shoujo" Movie                         0.000000
# 'Tis Time for "Torture," Princess              0.000000
# .hack//G.U. Returner                           0.078492
# ...                                                 ...
# xxxHOLiC◆Kei                                   1.000000
# Ōoku: The Inner Chambers                       0.000000
# ∀ Gundam                                       0.000000
# ∀ Gundam I: Earth Light                        0.000000
# ∀ Gundam II: Moonlight Butterfly               0.000000
#
#                                            Ōoku: The Inner Chambers  ∀ Gundam  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                       0.0  0.166478
# "Bungaku Shoujo" Memoire                                        0.0  0.179124
# "Bungaku Shoujo" Movie                                          0.0  0.000000
# 'Tis Time for "Torture," Princess                               0.0  0.000000
# .hack//G.U. Returner                                            0.0  0.000000
# ...                                                             ...       ...
# xxxHOLiC◆Kei                                                    0.0  0.000000
# Ōoku: The Inner Chambers                                        0.0  0.000000
# ∀ Gundam                                                        0.0  1.000000
# ∀ Gundam I: Earth Light                                         0.0  0.000000
# ∀ Gundam II: Moonlight Butterfly                                0.0  0.000000
#
#                                            ∀ Gundam I: Earth Light  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                      0.0
# "Bungaku Shoujo" Memoire                                       0.0
# "Bungaku Shoujo" Movie                                         0.0
# 'Tis Time for "Torture," Princess                              0.0
# .hack//G.U. Returner                                           0.0
# ...                                                            ...
# xxxHOLiC◆Kei                                                   0.0
# Ōoku: The Inner Chambers                                       0.0
# ∀ Gundam                                                       0.0
# ∀ Gundam I: Earth Light                                        0.0
# ∀ Gundam II: Moonlight Butterfly                               0.0
#
#                                            ∀ Gundam II: Moonlight Butterfly
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                               0.0
# "Bungaku Shoujo" Memoire                                                0.0
# "Bungaku Shoujo" Movie                                                  0.0
# 'Tis Time for "Torture," Princess                                       0.0
# .hack//G.U. Returner                                                    0.0
# ...                                                                     ...
# xxxHOLiC◆Kei                                                            0.0
# Ōoku: The Inner Chambers                                                0.0
# ∀ Gundam                                                                0.0
# ∀ Gundam I: Earth Light                                                 0.0
# ∀ Gundam II: Moonlight Butterfly                                        0.0
#
# [5915 rows x 5915 columns]

# %% [markdown]
# 由于我们的anime数量太多，所以计算similarity 需要花很长时间,所以使用了并行计算

# %%
def item_based_recommendation(similarity_matrix, matrix, top_n=5000, user_index=None, anime_index=None):
    """
    计算用户对动漫的推荐评分 r_ix。
    
    参数:
    - similarity_matrix: 动漫之间的相似度矩阵 (DataFrame)
    - matrix: 用户对动漫的评分矩阵 (DataFrame)
    - top_n: 考虑的与动漫 i 相似的前 N 个动漫 (int)
    - user_index: 用户的索引 (str)
    - anime_index: 当前动漫的索引 (str)
    
    返回:
    - 推荐评分 r_ix (float)
    """
    
    # 检查 anime_index 是否在 rating_matrix 中
    if anime_index not in matrix.index:
        print(f"动漫 {anime_index} 不在评分矩阵中。")
        return 0  # 或者返回一个合适的默认值

    # 检查 user_index 是否在 rating_matrix 中
    if user_index not in matrix.columns:
        print(f"用户 {user_index} 不在评分矩阵中。")
        return 0  # 或者返回一个合适的默认值

    # 获取用户对该动漫的评分
    user_rating = matrix.loc[anime_index, user_index]  # 使用 .loc

    # 如果评分不为 0，直接返回该评分
    if user_rating != 0:
        return user_rating
    
    # 提取动漫 i 的相似度和用户的评分
    sim_scores = similarity_matrix.loc[anime_index, :].values  # 使用 .loc
    ratings = matrix.loc[:, user_index].values  # 使用 .loc，获取用户的评分

    # 找到与动漫 i 最相似的前 N 个动漫的索引
    similar_indices = np.argsort(sim_scores)[-top_n:][::-1]

    # 计算推荐评分 r_ix
    numerator = 0  # 分子
    denominator = 0  # 分母
    
    for j in similar_indices:
        if ratings[j] > 0:  # 只考虑用户已评分的动漫
            numerator += sim_scores[j] * ratings[j]
            denominator += sim_scores[j]

    # 避免除以零
    if denominator > 0:
        return numerator / denominator
    else:
        return 0  # 如果没有相似度，返回 0

# %%
#an example for showing that function can work successfully
a = 'Ah My Buddha Katsu'
if a not in rating_matrix.index:
        print(f"动漫 {a} 不在评分矩阵中。")
u = 'AHKO'
sim_scores = sim.loc[a, :].values  # 使用 .loc
print(sim_scores)
print(sim_scores.size)
# Out:
# [0.04385992 0.08075026 0.11416927 ... 0.02025008 0.         0.        ]
# 5915

# %%
test_matrix = df_to_matrix(df)
print(test_matrix)
# Out:
#                                            13thokazaki  AAelpaso  AHKO  AMVP  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi            0         0     0     0
# "Bungaku Shoujo" Memoire                             0         0     0     0
# "Bungaku Shoujo" Movie                               0         0     0     0
# 'Tis Time for "Torture," Princess                    0         0     0     0
# .hack//G.U. Returner                                 0         0     0     0
# ...                                                ...       ...   ...   ...
# xxxHOLiC◆Kei                                         0         0     0     0
# Ōoku: The Inner Chambers                             0         0     0     0
# ∀ Gundam                                             0         0     0     0
# ∀ Gundam I: Earth Light                              0         0     0     0
# ∀ Gundam II: Moonlight Butterfly                     0         0     0     0
#
#                                            Abraxus  Absolom  Ainsley  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi        0        0        0
# "Bungaku Shoujo" Memoire                         0        0        0
# "Bungaku Shoujo" Movie                           0        0        0
# 'Tis Time for "Torture," Princess                0        0        0
# .hack//G.U. Returner                             0        0        0
# ...                                            ...      ...      ...
# xxxHOLiC◆Kei                                     0        0        0
# Ōoku: The Inner Chambers                         0        0        0
# ∀ Gundam                                         0        0        0
# ∀ Gundam I: Earth Light                          0        0        0
# ∀ Gundam II: Moonlight Butterfly                 0        0        0
#
#                                            Airashii  Ak38  Aleuuu  ...  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi         0     0       0  ...
# "Bungaku Shoujo" Memoire                          0     0       0  ...
# "Bungaku Shoujo" Movie                            0     0       0  ...
# 'Tis Time for "Torture," Princess                 0     0       0  ...
# .hack//G.U. Returner                              0     0       0  ...
# ...                                             ...   ...     ...  ...
# xxxHOLiC◆Kei                                      0     0       0  ...
# Ōoku: The Inner Chambers                          0     0       0  ...
# ∀ Gundam                                          0     0       0  ...
# ∀ Gundam I: Earth Light                           0     0       0  ...
# ∀ Gundam II: Moonlight Butterfly                  0     0       0  ...
#
#                                            unfathomable1  uraharashaylla  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi              0               0
# "Bungaku Shoujo" Memoire                               0               0
# "Bungaku Shoujo" Movie                                 0               0
# 'Tis Time for "Torture," Princess                      0               0
# .hack//G.U. Returner                                   0               0
# ...                                                  ...             ...
# xxxHOLiC◆Kei                                           0              10
# Ōoku: The Inner Chambers                               0               0
# ∀ Gundam                                               0               0
# ∀ Gundam I: Earth Light                                0               0
# ∀ Gundam II: Moonlight Butterfly                       0               0
#
#                                            vizard21  wartsu  xKimPANIC  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi         0       0          0
# "Bungaku Shoujo" Memoire                          0       0          0
# "Bungaku Shoujo" Movie                            0       0          0
# 'Tis Time for "Torture," Princess                 0       0          0
# .hack//G.U. Returner                              0       0          0
# ...                                             ...     ...        ...
# xxxHOLiC◆Kei                                      0       0          0
# Ōoku: The Inner Chambers                          0       0          0
# ∀ Gundam                                          0       0          0
# ∀ Gundam I: Earth Light                           0       0          0
# ∀ Gundam II: Moonlight Butterfly                  0       0          0
#
#                                            xxbladexx20  yanmzry  yousif  \
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi            0        0       0
# "Bungaku Shoujo" Memoire                             0        0       0
# "Bungaku Shoujo" Movie                               0        0       0
# 'Tis Time for "Torture," Princess                    0        0       0
# .hack//G.U. Returner                                 0        0       0
# ...                                                ...      ...     ...
# xxxHOLiC◆Kei                                         0        9       0
# Ōoku: The Inner Chambers                             0        0       0
# ∀ Gundam                                             0        0       0
# ∀ Gundam I: Earth Light                              0        0       0
# ∀ Gundam II: Moonlight Butterfly                     0        0       0
#
#                                            zephyr0x  zsaberslash
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi         0            0
# "Bungaku Shoujo" Memoire                          0            0
# "Bungaku Shoujo" Movie                            0            0
# 'Tis Time for "Torture," Princess                 0            0
# .hack//G.U. Returner                              0            0
# ...                                             ...          ...
# xxxHOLiC◆Kei                                      0            0
# Ōoku: The Inner Chambers                          0            0
# ∀ Gundam                                          0            0
# ∀ Gundam I: Earth Light                           0            0
# ∀ Gundam II: Moonlight Butterfly                  0            0
#
# [5915 rows x 601 columns]

# %%
ratings = test_matrix.loc[:, u].values  # 使用 .loc，获取用户的评分
print(ratings.size)
# Out:
# 5915

# %%
i = item_based_recommendation(sim, test_matrix, user_index=u, anime_index=a)
print(i)
# Out:
# 7.558904144268643

# %%
def calculate_all_recommendations(similarity_matrix, rating_matrix, user_index, top_n=100):
    """
    计算用户对所有动漫的推荐评分，并选出前 N 部评分最高的动漫。
    
    参数:
    - similarity_matrix: 动漫之间的相似度矩阵 (DataFrame)
    - rating_matrix: 用户对动漫的评分矩阵 (DataFrame)
    - user_index: 用户的索引 (str)
    - top_n: 返回前 N 部评分最高的动漫 (int)

    返回:
    - 推荐动漫及其评分 (DataFrame)
    """
    n_animes = rating_matrix.shape[0]  # 动漫数量
    recommended_ratings = []

    for anime_index in rating_matrix.index:  # 使用行名（动漫名称）
        rating = item_based_recommendation(similarity_matrix, rating_matrix, user_index=user_index, anime_index=anime_index)
        recommended_ratings.append((anime_index, rating))

    # 创建 DataFrame 存储推荐评分
    ratings_df = pd.DataFrame(recommended_ratings, columns=['Anime Name', 'Predicted Rating'])
    
    # 选出评分最高的前 N 部动漫
    top_recommendations = ratings_df.sort_values(by='Predicted Rating', ascending=False).head(top_n)
    
    return top_recommendations

# %%
print(test_matrix.columns.tolist())
# Out:
# ['13thokazaki', 'AAelpaso', 'AHKO', 'AMVP', 'Abraxus', 'Absolom', 'Ainsley', 'Airashii', 'Ak38', 'Aleuuu', 'Amatire', 'Ame-', 'Amu_Himamori', 'Amyndele', 'Anime-Angel', 'AnimeCrown', 'AnimeFreaky66', 'Anorien', 'Arbalest270', 'AsbjornSB', 'AtomicFuse', 'Away', 'Axel_friki', 'Axryn3713', 'AziChan', 'Bakadragon', 'Bedlam', 'BionicM', 'Black7ven', 'BladeXian', 'Blaquestarr', 'BloodySaya', 'Bmberman', 'BroomR', 'CTEvergreen', 'Cambeca', 'Cao', 'Carolch', 'Cashew', 'Catgirl-Lover', 'Catrah', 'Celestra', 'Ceske', 'Chabiorek', 'Chemik89', 'ChronoSaber', 'Church', 'Cinderella', 'Clia', 'Coakes', 'ColitaCheyenne', 'CookieStar', 'CorporalChaos', 'Cr0w', 'CyanideSlavery', 'D-Ryu77', 'DEATH-BRINGER', 'DEXUS', 'DHT', 'DR3AMKLLR', 'Daaphan', 'Dabbagh', 'Damyen', 'Dandelion15', 'Dandy_Sephy', 'Danimal', 'DarkMooN', 'DarkShon', 'Darylmh', 'Degar', 'Dekar', 'Delish', 'Demonwynd', 'Denjin', 'DentalSupplies', 'DerNoob', 'Desirecaged', 'Dkosty', 'DragonEye58', 'Dragonalchemest', 'Drkness19', 'Dulb', 'ERETEG', 'Elfire', 'Elladriel', 'Emphy', 'Emrh20', 'Ender_Wiggin', 'Errk', 'EusthEnoptEron', 'EviLSasukeUchiha', 'Evie', 'EvoLxDark', 'Exarius', 'Femboylicious', 'Flashgun', 'Flauen', 'Flikkr', 'Frash', 'FreakyDeaky', 'Funkativity', 'Furuba', 'Fushi', 'Gambitsx', 'Gamehi', 'GamerMan76', 'Gearfried', 'Geech', 'GekkoHeaven', 'GeneralMotors', 'Genjuro', 'Germanturkey', 'Ghiin', 'Gille', 'Gozu', 'Gray_Aria', 'Gremico', 'Grepsd', 'GunarmDyne', 'Haruki-kun', 'Hatchett', 'Heathers_a_Neko', 'Heliocentric', 'Hellshreder', 'Higashi', 'Hikari_Sinclair', 'Hikaru_Asakura', 'Hollow_Pein', 'Homolun7', 'Icarus', 'Insomne', 'IntenseAllure', 'Ione', 'Iruel89', 'Ishida_100', 'Ismar', 'JayMoon777', 'Jirachii', 'Joix', 'Joketsu', 'Josue_Light', 'JuggyCL', 'Juiceman3024', 'Juliette', 'Juvefc417', 'KageKin', 'Kalen2k', 'Kamina-Q8', 'Kandaisle_15', 'Kap13', 'KarinNahara12', 'Karism', 'Karkis', 'Kataki', 'Katsumi_Kawaii', 'Kaya', 'Kaylanna', 'Kazik', 'Kentaro-kun', 'Keyray', 'Kiiroikitsune', 'KinG_VigoR', 'Kirachan', 'KittyCue', 'Knyves', 'KoMew', 'KonataIsMyWife', 'KossD', 'KrIsz', 'Kracks', 'KrisZero', 'KroryLover', 'Krumas', 'Kunoichi27', 'Kusabi', 'LMP', 'Lady_Yavanna', 'LaoShrHao', 'Lawliets_Cake', 'Lee_Xtremist', 'Lemondrips', 'LghtChaos', 'LibbyChue', 'LiisuT', 'Lilyaa', 'LinLou', 'LordStrider', 'LoveInFullBloom', 'Lucy_Flrs', 'LukeXCage', 'Lulumay', 'MADB', 'Maattrue', 'MabuiKoneko', 'Magickyak', 'Makoto_Hikawa', 'Mallu', 'MandyPandy', 'Manuel', 'MardukGX', 'Maruda', 'Methelan', 'Meyvi', 'Misako', 'Miyako', 'Modrzew', 'Morders', 'MorningWood', 'Mozi1991', 'MrSilent', 'MugenPein', 'Mune', 'MySoxRock', 'Na00', 'Nana13', 'NaoGene', 'Negaigoto', 'NiLoBakA', 'Nightwing-', 'NivGol', 'NocturneWolf', 'Nooooooo', 'Np3228', 'Obsid', 'Oodi', 'Orblivion', 'OutstandAce170', 'Oyakatasama4ever', 'PBz0r', 'PLUSULTRAAAAAAA', 'Painted_Outlaw', 'Patterson', 'Pete2R', 'Philian', 'PhillipDSX', 'Phrodo_00', 'Pierrrot', 'Pigwidgeon', 'Pitacoatl', 'Pontifus', 'Princess-Serena', 'PvtBourque', 'Pyschojo', 'Quintasan', 'RAIKAGE', 'RaQziom', 'Ragnarok4', 'Rago42', 'Rai-chan', 'Ratsugo', 'Razgriz1', 'Rege', 'Reservoir', 'Rio_Senna', 'Robertthesmall', 'RodG', 'Rue', 'Rynax', 'Ryohei94', 'SAF', 'SERENiTY_43', 'SF6', 'Saiyaou', 'Sajuri', 'SalemJericho', 'Salt_', 'Sanguina', 'SatanField', 'Saturnus', 'SayaRikuMao', 'SchoolDaysd00d', 'Sekai-chan', 'Senozza', 'Sephiria', 'Shaah', 'Shaddox', 'ShiroiOnna', 'Shiroyasha', 'Shojimonk', 'Sieg', 'Sinlaw', 'Skald', 'SmalltinyOrange', 'Smooth_Ass', 'Sorrow-kun', 'Spike__', 'Splandit', 'Sukotto', 'Superpsychol', 'SuppaKiwiMon', 'SvenneMEan', 'Sylpheed', 'TakKi', 'Tara-chan', 'TaraFitz', 'Tass', 'Tasslehoff', 'Tatsu', 'Tawsie', 'Tebbie', 'The_Mouse', 'Tinithraviel', 'Tom_Tom', 'Tonedeff', 'Totti-chan', 'Tragikidol', 'Trick_Buster', 'TrueBooleanFalse', 'Tsutsuya', 'Twardki_Slovian', 'Txileno', 'Tyfon', 'Tynan', 'Uky', 'Unholy4orce', 'UomoTigre', 'VAZH', 'Valthonis', 'VanguardsArk', 'Varjotar', 'Vellocet', 'VinnyJ', 'WOOLAN', 'Waffle-Sama', 'WhiteGringo80', 'Wopsi ...

# %%
print(test_matrix.index.tolist())
# Out:
# ['"Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi', '"Bungaku Shoujo" Memoire', '"Bungaku Shoujo" Movie', '\'Tis Time for "Torture," Princess', '.hack//G.U. Returner', '.hack//G.U. Trilogy', '.hack//G.U. Trilogy: Parody Mode', '.hack//Gift', '.hack//Intermezzo', '.hack//Legend of The Twilight', '.hack//Legend of the Twilight Offline Meeting Special', '.hack//Liminality', '.hack//Quantum', '.hack//Quantum: Go, Our Chim Chims!!', '.hack//Roots', '.hack//Sign', '.hack//Unison', '0-saiji Start Dash Monogatari', '009 Re:Cyborg', '009-1', '009-1: R&B', '07-Ghost', '1+2=Paradise', '100 Sleeping Princes and the Kingdom of Dreams', '1000-nen Joou: Queen Millennia', '1001 Nights', '11eyes', '11eyes: Momoiro Genmutan', '12-sai.: Chicchana Mune no Tokimeki', '15 Bishoujo Hyouryuuki', '16bit Sensation: Another Layer', '18if', '2.43: Seiin High School Boys Volleyball Team', '2.5 Dimensional Seduction', '21-ji no Onna: Newscaster Katsuragi Miki', '22/7', '22/7: 8＋3=?', '25-Year-Old High School Girl, I Wouldn’t Do This with a Kid', '30th Gundam Perfect Mission', '365 Days to the Wedding', '3x3 Eyes', '3x3 Eyes: Legend of the Divine Demon', '4-Day Weekend', '5 Centimeters per Second', '6 Angels', '7 Seeds', '7 Seeds 2nd Season', '7th Time Loop: The Villainess Enjoys a Carefree Life Married to Her Worst Enemy!', '8 Man After', '801 T.T.S. Airbats', '86 Eighty-Six', '86 Eighty-Six Part 2', '91 Days', '91 Days: Brief Candle', '91 Days: Shoal of Time/All Our Yesterdays/Tomorrow and Tomorrow', 'A Bridge to the Starry Skies', "A Centaur's Life", 'A Certain Magical Index', 'A Certain Magical Index II', 'A Certain Magical Index II: Specials', 'A Certain Magical Index III', 'A Certain Magical Index the Movie: The Miracle of Endymion', 'A Certain Magical Index: Specials', 'A Certain Scientific Accelerator', 'A Certain Scientific Railgun', 'A Certain Scientific Railgun S', 'A Certain Scientific Railgun S: All the Important Things I Learned in a Bathhouse', 'A Certain Scientific Railgun T', 'A Chinese Ghost Story', 'A Condition Called Love', 'A Couple of Cuckoos', 'A Dark Rabbit has Seven Lives', 'A Farewell to Arms', 'A Forbidden Time', 'A Foreign Love Affair', 'A Galaxy Next Door', 'A Girl & Her Guard Dog', 'A Good Librarian Like a Good Shepherd', 'A Heat for All Seasons', 'A Herbivorous Dragon of 5,000 Years Gets Unfairly Villainized', 'A Hot Night With My Boss in a Capsule Hotel', 'A Journey Through Another World: Raising Kids While Adventuring', 'A Kiss for the Petals: Becoming Your Lover', 'A Letter to Momo', 'A Little Princess Sara', 'A Little Snow Fairy Sugar', 'A Lull in the Sea', "A Nobody's Way Up to an Exploration Hero", 'A Place Further Than The Universe', "A Playthrough of a Certain Dude's VRMMO Life", "A Returner's Magic Should Be Special", 'A Salad Bowl of Eccentrics', 'A Sign of Affection', 'A Silent Voice', "A Sister's All You Need", 'A Strange Kind of Woman', 'A Summer-Colored Miracle', "A Sumo Wrestler's Tail", 'A Terrified Teacher at Ghoul School!', "A Thirty-Year Old's Health and Physical Education", 'A Town Where You Live', 'A Town Where You Live: Crossing at Twilight', "A Traveller's Diary", "A Traveller's Diary Specials", 'A Tree of Palme', 'A Whisker Away', 'A Wind Named Amnesia', 'A-Channel', 'A-Channel+smile', 'A-Channel: +A-Channel', 'A.D. Police: To Protect and Serve', 'A.I.C.O. Incarnation', 'A.LI.CE', 'A3! Season Spring & Summer', 'ACCA: 13-Territory Inspection Dept.', 'AD Police Files', 'AHO-GIRL', 'AIKa R-16: Virgin Mission', 'AIKa Zero', 'AIKa Zero Picture Drama', 'AIKa: Special Trial', 'AKB0048', 'AKB0048: Next Stage', 'AMAIM Warrior at the Borderline', 'AMAIM Warrior at the Borderline Part 2', 'AMAIM: Warrior at the Borderline UltraSteel Ogre-Gear', 'Aa Harimanada', 'Aachi and Ssipak', 'Abashiri Ikka', 'Absolute Duo', 'Accel World', 'Accel World EX', 'Accel World: Acchel World.', 'Accel World: Infinite∞Burst', 'Accelerando: Datenshi-tachi no Sasayaki', 'Acchi Kocchi: Place=Princess', 'Ace Attorney', 'Ace Attorney Season 2',  ...

# %%
matrix = calculate_all_recommendations(sim, test_matrix, u)
print(matrix)
# Out:
#                                   Anime Name  Predicted Rating
# 618                                  Berserk         10.000000
# 5743                             Wolf's Rain         10.000000
# 1657                                    FLCL         10.000000
# 1576                        Eden of The East         10.000000
# 2778                                   Karas         10.000000
# ...                                      ...               ...
# 1785                     Flying Phantom Ship          8.652643
# 3161  Lupin III Episode 0: The First Contact          8.597436
# 1232                       Dance with Devils          8.593071
# 4404               Resident Evil 4D Executor          8.564154
# 2312                        Heroman Specials          8.564154
#
# [100 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error
def fill_zero_ratings(similarity_matrix, matrix, top_n=5000):
    filled_matrix = matrix.copy()
    original_ratings = {}  # 用于存储原始评分

    # 仅选择前500个用户评分
    user_columns = filled_matrix.columns[:500]

    # 遍历每个动漫
    for anime_index in filled_matrix.index:
        for user_index in user_columns:
            # 记录原始评分并将其变为0
            if filled_matrix.loc[anime_index, user_index] > 0:
                original_ratings[(anime_index, user_index)] = filled_matrix.loc[anime_index, user_index]
                filled_matrix.loc[anime_index, user_index] = 0  # 将评分变为0

    # 重新计算评分（对原本有评分的条目）
    for anime_index in filled_matrix.index:
        for user_index in user_columns:
            if (anime_index, user_index) in original_ratings:  # 仅对原本有评分的条目计算推荐评分
                recommended_rating = item_based_recommendation(
                    similarity_matrix,
                    filled_matrix,
                    top_n,
                    user_index,
                    anime_index
                )
                filled_matrix.loc[anime_index, user_index] = recommended_rating

    return filled_matrix, original_ratings

# 计算均方误差，限制为前500个用户
def calculate_mae(original_ratings, filled_matrix):
    y_true = []
    y_pred = []

    # 仅选择前500个用户评分
    user_columns = filled_matrix.columns[:500]

    for (anime_index, user_index), original_rating in original_ratings.items():
        if user_index in user_columns:  # 仅计算前500个用户的评分
            y_true.append(original_rating)
            y_pred.append(filled_matrix.loc[anime_index, user_index])

    return mean_absolute_error(y_true, y_pred)

# %%
#我们就计算前面500个用户的评分误差（error）
filled_matrix, original_ratings = fill_zero_ratings(sim, test_matrix, top_n=5000)
mae = calculate_mae(original_ratings, filled_matrix)
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 7.659398003428456
